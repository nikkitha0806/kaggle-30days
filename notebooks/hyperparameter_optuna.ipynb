# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.metrics import mean_absolute_error, mean_squared_error
from xgboost import XGBRegressor
import optuna

import warnings
warnings.filterwarnings("ignore")

# %%
#import data:
data = pd.read_csv("../../kaggle-30days/data/train_folds/train_folds.csv")
#shuffle the data:
data_full= data.sample(frac=1)

# %%
#training data: 
#Note: since test data is not available:
df = data_full.iloc[:240000,:]
df_test = data_full.iloc[240000:,:]

# %%
useful_features = [c for c in df.columns if c not in ["id","target","kfold"]]
object_cols = [c for c in useful_features if c.startswith("cat")]
df_test = df_test[useful_features]

# %%
#target encoding:
for col in object_cols:
    temp_df = []
    temp_test_feat =None
    for fold in range(5):
        xtrain =  df[df.kfold != fold].reset_index(drop=True)
        xvalid = df[df.kfold == fold].reset_index(drop=True)
        feat = xtrain.groupby(col)["target"].agg("mean")
        feat = feat.to_dict()
        print(feat)
        xvalid.loc[:, f"tar_enc_{col}"] = xvalid[col].map(feat)
        print(xvalid.head())
        temp_df.append(xvalid)
        if temp_test_feat is None:
            temp_test_feat = df_test[col].map(feat)
        else:
            temp_test_feat += df_test[col].map(feat) 
    
    #calculate the value for each fold and then divide by 5:
    temp_test_feat /= 5
    df_test.loc[:, f"tar_enc_{col}"] = temp_test_feat
    df = pd.concat(temp_df)
    print("df",df)
# Out:
# {'A': 8.237357916702521, 'B': 8.249206864369928}
#        id cat0 cat1 cat2  ...    cont13    target kfold tar_enc_cat0
# 0   97127    A    A    A  ...  0.189804  8.884669     0     8.237358
# 1   28518    A    A    A  ...  0.857538  9.041808     0     8.237358
# 2  289922    B    A    B  ...  0.764259  7.428308     0     8.249207
# 3  265997    B    A    A  ...  0.425692  8.327012     0     8.249207
# 4  103360    B    A    A  ...  0.708118  8.630546     0     8.249207
#
# [5 rows x 28 columns]
# {'A': 8.237168140863156, 'B': 8.249228725855923}
#        id cat0 cat1 cat2  ...    cont13    target kfold tar_enc_cat0
# 0  488880    B    B    A  ...  0.818652  9.339204     1     8.249229
# 1  357806    A    B    A  ...  0.843537  8.117776     1     8.237168
# 2   41431    B    B    A  ...  0.587890  8.200927     1     8.249229
# 3  188016    A    A    A  ...  0.287837  8.823878     1     8.237168
# 4  327993    A    A    A  ...  0.202111  9.081631     1     8.237168
#
# [5 rows x 28 columns]
# {'A': 8.23817247947091, 'B': 8.249024617101867}
#        id cat0 cat1 cat2  ...    cont13    target kfold tar_enc_cat0
# 0  144377    A    A    A  ...  0.648895  8.608907     2     8.238172
# 1  371205    A    B    A  ...  0.620729  7.019098     2     8.238172
# 2   10724    B    A    A  ...  0.761979  8.108192     2     8.249025
# 3  368563    B    A    A  ...  0.714992  8.034682     2     8.249025
# 4   16125    B    A    A  ...  0.451163  8.654783     2     8.249025
#
# [5 rows x 28 columns]
# {'A': 8.237492241548704, 'B': 8.247945263839913}
#        id cat0 cat1 cat2  ...    cont13    target kfold tar_enc_cat0
# 0  214778    A    B    A  ...  0.201525  7.180367     3     8.237492
# 1   91330    A    B    A  ...  0.427171  8.270042     3     8.237492
# 2   95512    A    B    B  ...  0.294020  7.920226     3     8.237492
# 3  106711    A    B    A  ...  0.273207  8.441344     3     8.237492
# 4  212946    B    A    A  ...  0.828638  7.443076     3     8.247945
#
# [5 rows x 28 columns]
# {'A': 8.23772253446005, 'B': 8.24549758856122}
#        id cat0 cat1 cat2  ...    cont13    target kfold tar_enc_cat0
# 0  424309    B    A    A  ...  0.763019  7.615672     4     8.245498
# 1  373239    A    B    A  ...  0.336388  7.886911     4     8.237723
# 2  493757    B    B    A  ...  0.863103  6.984641     4     8.245498
# 3   24125    A    A    A  ...  0.469829  8.518811     4     8.237723
# 4  312331    A    A    A  ...  0.695126  8.405185     4     8.237723
#
# [5 rows x 28 columns]
# df            id cat0 cat1 cat2  ...    cont13    target kfold tar_enc_cat0
# 0       97127    A    A    A  ...  0.189804  8.884669     0     8.237358
# 1       28518    A    A    A  ...  0.857538  9.041808     0     8.237358
# 2      289922    B    A    B  ...  0.764259  7.428308     0     8.249207
# 3      265997    B    A    A  ...  0.425692  8.327012     0     8.249207
# 4      103360    B    A    A  ...  0.708118  8.630546     0     8.249207
# ...       ...  ...  ...  ...  ...       ...       ...   ...          ...
# 47935  459632    A    A    A  ...  0.797256  7.968289     4     8.237723
# 47936  432458    B    A    A  ...  0.326452  8.088297     4     8.245498
# 47937  413623    A    A    A  ...  0.164810  7.517437     4     8.237723
# 47938  158228    A    B    A  ...  0.471487  7.866204     4     8.237723
# 47939  170223    A    A    A  ...  0.250461  8.358065     4     8.237723
#
# [240000 rows x 28 columns]
# {'A': 8.276967583172375, 'B': 8.20370718226016}
#        id cat0 cat1 cat2  ...    target kfold tar_enc_cat0 tar_enc_cat1
# 0   97127    A    A    A  ...  8.884669     0     8.237358     8.276968
# 1   28518    A    A    A  ...  9.041808     0     8.237358     8.276968
# 2  289922    B    A    B  ...  7.428308     0     8.249207     8.276968
# 3  265997    B    A    A  ...  8.327012     0     8.249207     8.276968
# 4  103360    B    A    A  ...  8.630546     0     8.249207     8.276968
#
# [5 rows x 29 columns]
# {'A': 8.276917063766497, 'B': 8.203718332683875}
#        id cat0 cat1 cat2  ...    target kfold tar_enc_cat0 tar_enc_cat1
# 0  488880    B    B    A  ...  9.339204     1     8.249229     8.203718
# 1  357806    A    B    A  ...  8.117776     1     8.237168     8.203718
# 2   41431    B    B    A  ...  8.200927     1     8.249229     8.203718
# 3  188016    A    A    A  ...  8.823878     1     8.237168     8.276917
# 4  327993    A    A    A  ...  9.081631     1     8.237168     8.276917
#
# [5 rows x 29 columns]
# {'A': 8.278212452058355, 'B': 8.20349727304021}
#        id cat0 cat1 cat2  ...    target kfold tar_enc_cat0 tar_enc_cat1
# 0  144377    A    A    A  ...  8.608907     2     8.238172     8.278212
# 1  371205    A    B    A  ...  7.019098     2     8.238172     8.203497
# 2   10724    B    A    A  ...  8.108192     2     8.249025     8.278212
# 3  368563    B    A    A  ...  8.034682     2     8.249025     8.278212
# 4   16125    B    A    A  ...  8.654783     2     8.249025     8.278212
#
# [5 rows x 29 columns]
# {'A': 8.278911551522635, 'B': 8.200954431193102}
#        id cat0 cat1 cat2  ...    target kfold tar_enc_cat0 tar_enc_cat1
# 0  214778    A    B    A  ...  7.180367     3     8.237492     8.200954
# 1   91330    A    B    A  ...  8.270042     3     8.237492     8.200954
# 2   95512    A    B    B  ...  7.920226     3     8.237492     8.200954
# 3  106711    A    B    A  ...  8.441344     3     8.237492     8.200954
# 4  212946    B    A    A  ...  7.443076     3     8.247945     8.278912
#
# [5 rows x 29 columns]
# {'A': 8.276709539844857, 'B': 8.201880294091511}
#        id cat0 cat1 cat2  ...    target kfold tar_enc_cat0 tar_enc_cat1
# 0  424309    B    A    A  ...  7.615672     4     8.245498      8.27671
# 1  373239    A    B    A  ...  7.886911     4     8.237723      8.20188
# 2  493757    B    B    A  ...  6.984641     4     8.245498      8.20188
# 3   24125    A    A    A  ...  8.518811     4     8.237723      8.27671
# 4  312331    A    A    A  ...  8.405185     4     8.237723      8.27671
#
# [5 rows x 29 columns]
# df            id cat0 cat1 cat2  ...    target kfold tar_enc_cat0 tar_enc_cat1
# 0       97127    A    A    A  ...  8.884669     0     8.237358     8.276968
# 1       28518    A    A    A  ...  9.041808     0     8.237358     8.276968
# 2      289922    B    A    B  ...  7.428308     0     8.249207     8.276968
# 3      265997    B    A    A  ...  8.327012     0     8.249207     8.276968
# 4      103360    B    A    A  ...  8.630546     0     8.249207     8.276968
# ...       ...  ...  ...  ...  ...       ...   ...          ...          ...
# 47935  459632    A    A    A  ...  7.968289     4     8.237723     8.276710
# 47936  432458    B    A    A  ...  8.088297     4     8.245498     8.276710
# 47937  413623    A    A    A  ...  7.517437     4     8.237723     8.276710
# 47938  158228    A    B    A  ...  7.866204     4     8.237723     8.201880
# 47939  170223    A    A    A  ...  8.358065     4     8.237723     8.276710
#
# [240000 rows x 29 columns]
# {'A': 8.244615808957683, 'B': 8.224856268365869}
#        id cat0 cat1 cat2  ... kfold tar_enc_cat0 tar_enc_cat1 tar_enc_cat2
# 0   97127    A    A    A  ...     0     8.237358     8.276968     8.244616
# 1   28518    A    A    A  ...     0     8.237358     8.276968     8.244616
# 2  289922    B    A    B  ...     0     8.249207     8.276968     8.224856
# 3  265997    B    A    A  ...     0     8.249207     8.276968     8.244616
# 4  103360    B    A    A  ...     0     8.249207     8.276968     8.244616
#
# [5 rows x 30 columns]
# {'A': 8.244863063982859, 'B': 8.222562397347376}
#        id cat0 cat1 cat2  ... kfold tar_enc_cat0 tar_enc_cat1 tar_enc_cat2
# 0  488880    B    B    A  ...     1     8.249229     8.203718     8.244863
# 1  357806    A    B    A  ...     1     8.237168     8.203718     8.244863
# 2   41431    B    B    A  ...     1     8.249229     8.203718     8.244863
# 3  188016    A    A    A  ...     1     8.237168     8.276917     8.244863
# 4  327993    A    A    A  ...     1     8.237168     8.276917     8.244863
#
# [5 rows x 30 columns]
# {'A': 8.245127065429921, 'B': 8.22509769221099}
#        id cat0 cat1 cat2  ... kfold tar_enc_cat0 tar_enc_cat1 tar_enc_cat2
# 0  144377    A    A    A  ...     2     8.238172     8.278212     8.245127
# 1  371205    A    B    A  ...     2     8.238172     8.203497     8.245127
# 2   10724    B    A    A  ...     2     8.249025     8.278212     8.245127
# 3  368563    B    A    A  ...     2     8.249025     8.278212     8.245127
# 4   16125    B    A    A  ...     2     8.249025     8.278212     8.245127
#
# [5 rows x 30 columns]
# {'A': 8.24457019626376, 'B': 8.22284141021038}
#        id cat0 cat1 cat2  ... kfold tar_enc_cat0 tar_enc_cat1 tar_enc_cat2
# 0  214778    A    B    A  ...     3     8.237492     8.200954     8.244570
# 1   91330    A    B    A  ...     3     8.237492     8.200954     8.244570
# 2   95512    A    B    B  ...     3     8.237492     8.200954     8.222841
# 3  106711    A    B    A  ...     3     8.237492     8.200954     8.244570
# 4  212946    B    A    A  ...     3     8.247945     8.278912     8.244570
#
# [5 rows x 30 columns]
# {'A': 8.243585087534305, 'B': 8.223475850857588}
#        id cat0 cat1 cat2  ... kfold tar_enc_cat0 tar_enc_cat1 tar_enc_cat2
# 0  424309    B    A    A  ...     4     8.245498      8.27671     8.243585
# 1  373239    A    B    A  ...     4     8.237723      8.20188     8.243585
# 2  493757    B    B    A  ...     4     8.245498      8.20188     8.243585
# 3   24125    A    A    A  ...     4     8.237723      8.27671     8.243585
# 4  312331    A    A    A  ...     4     8.237723      8.27671     8.243585
#
# [5 rows x 30 columns]
# df            id cat0 cat1 cat2  ... kfold tar_enc_cat0 tar_enc_cat1 tar_enc_cat2
# 0       97127    A    A    A  ...     0     8.237358     8.276968     8.244616
# 1       28518    A    A    A  ...     0     8.237358     8.276968     8.244616
# 2      289922    B    A    B  ...     0     8.249207     8.276968     8.224856
# 3      265997    B    A    A  ...     0     8.249207     8.276968     8.244616
# 4      103360    B    A    A  ...     0     8.249207     8.276968     8.244616
# ...       ...  ...  ...  ...  ...   ...          ...          ...          ...
# 47935  459632    A    A    A  ...     4     8.237723     8.276710     8.243585
# 47936  432458    B    A    A  ...     4     8.245498     8.276710     8.243585
# 47937  413623    A    A    A  ...     4     8.237723     8.276710     8.243585
# 47938  158228    A    B    A  ...     4     8.237723     8.201880     8.243585
# 47939  170223    A    A    A  ...     4     8.237723     8.276710     8.243585
#
# [240000 rows x 30 columns]
# {'A': 8.272189214136219, 'B': 8.368743228707329, 'C': 8.23710569032115, 'D': 8.273070020038343}
#        id cat0 cat1  ... tar_enc_cat1 tar_enc_cat2 tar_enc_cat3
# 0   97127    A    A  ...     8.276968     8.244616     8.272189
# 1   28518    A    A  ...     8.276968     8.244616     8.237106
# 2  289922    B    A  ...     8.276968     8.224856     8.237106
# 3  265997    B    A  ...     8.276968     8.244616     8.237106
# 4  103360    B    A  ...     8.276968     8.244616     8.237106
#
# [5 rows x 31 columns]
# {'A': 8.277751733957384, 'B': 8.37258134768906, 'C': 8.236432385834979, 'D': 8.263595878609232}
#        id cat0 cat1  ... tar_enc_cat1 tar_enc_cat2 tar_enc_cat3
# 0  488880    B    B  ...     8.203718     8.244863     8.236432
# 1  357806    A    B  ...     8.203718     8.244863     8.236432
# 2   41431    B    B  ...     8.203718     8.244863     8.236432
# 3  188016    A    A  ...     8.276917     8.244863     8.236432
# 4  327993    A    A  ...     8.276917     8.244863     8.236432
#
# [5 rows x 31 columns]
# {'A': 8.275834162688007, 'B': 8.395434473389571, 'C': 8.237132001024255, 'D': 8.272418764179003}
#        id cat0 cat1  ... tar_enc_cat1 tar_enc_cat2 tar_enc_cat3
# 0  144377    A    A  ...     8.278212     8.245127     8.237132
# 1  371205    A    B  ...     8.203497     8.245127     8.275834
# 2   10724    B    A  ...     8.278212     8.245127     8.237132
# 3  368563    B    A  ...     8.278212     8.245127     8.237132
# 4   16125    B    A  ...     8.278212     8.245127     8.237132
#
# [5 rows x 31 columns]
# {'A': 8.275886619124195, 'B': 8.39167336293412, 'C': 8.236194955434733, 'D': 8.272376085091022}
#        id cat0 cat1  ... tar_enc_cat1 tar_enc_cat2 tar_enc_cat3
# 0  214778    A    B  ...     8.200954     8.244570     8.236195
# 1   91330    A    B  ...     8.200954     8.244570     8.236195
# 2   95512    A    B  ...     8.200954     8.222841     8.236195
# 3  106711    A    B  ...     8.200954     8.244570     8.236195
# 4  212946    B    A  ...     8.278912     8.244570     8.236195
#
# [5 rows x 31 columns]
# {'A': 8.276837608290204, 'B': 8.376255218307676, 'C': 8.235270822985957, 'D': 8.273702199263793}
#        id cat0 cat1  ... tar_enc_cat1 tar_enc_cat2 tar_enc_cat3
# 0  424309    B    A  ...      8.27671     8.243585     8.235271
# 1  373239    A    B  ...      8.20188     8.243585     8.235271
# 2  493757    B    B  ...      8.20188     8.243585     8.235271
# 3   24125    A    A  ...      8.27671     8.243585     8.235271
# 4  312331    A    A  ...      8.27671     8.243585     8.235271
#
# [5 rows x 31 columns]
# df            id cat0 cat1  ... tar_enc_cat1 tar_enc_cat2 tar_enc_cat3
# 0       97127    A    A  ...     8.276968     8.244616     8.272189
# 1       28518    A    A  ...     8.276968     8.244616     8.237106
# 2      289922    B    A  ...     8.276968     8.224856     8.237106
# 3      265997    B    A  ...     8.276968     8.244616     8.237106
# 4      103360    B    A  ...     8.276968     8.244616     8.237106
# ...       ...  ...  ...  ...          ...          ...          ...
# 47935  459632    A    A  ...     8.276710     8.243585     8.235271
# 47936  432458    B    A  ...     8.276710     8.243585     8.235271
# 47937  413623    A    A  ...     8.276710     8.243585     8.235271
# 47938  158228    A    B  ...     8.201880     8.243585     8.235271
# 47939  170223    A    A  ...     8.276710     8.243585     8.235271
#
# [240000 rows x 31 columns]
# {'A': 8.265117296717065, 'B': 8.24093174944737, 'C': 8.302294102770773, 'D': 8.265288247987835}
#        id cat0 cat1  ... tar_enc_cat2 tar_enc_cat3 tar_enc_cat4
# 0   97127    A    A  ...     8.244616     8.272189     8.240932
# 1   28518    A    A  ...     8.244616     8.237106     8.240932
# 2  289922    B    A  ...     8.224856     8.237106     8.240932
# 3  265997    B    A  ...     8.244616     8.237106     8.240932
# 4  103360    B    A  ...     8.244616     8.237106     8.240932
#
# [5 rows x 32 columns]
# {'A': 8.272864325589671, 'B': 8.240741270821383, 'C': 8.299730962852774, 'D': 8.262649675761082}
#        id cat0 cat1  ... tar_enc_cat2 tar_enc_cat3 tar_enc_cat4
# 0  488880    B    B  ...     8.244863     8.236432     8.240741
# 1  357806    A    B  ...     8.244863     8.236432     8.240741
# 2   41431    B    B  ...     8.244863     8.236432     8.240741
# 3  188016    A    A  ...     8.244863     8.236432     8.240741
# 4  327993    A    A  ...     8.244863     8.236432     8.240741
#
# [5 rows x 32 columns]
# {'A': 8.281744361388219, 'B': 8.241172735189942, 'C': 8.317782352258796, 'D': 8.244868443944045}
#        id cat0 cat1  ... tar_enc_cat2 tar_enc_cat3 tar_enc_cat4
# 0  144377    A    A  ...     8.245127     8.237132     8.241173
# 1  371205    A    B  ...     8.245127     8.275834     8.241173
# 2   10724    B    A  ...     8.245127     8.237132     8.241173
# 3  368563    B    A  ...     8.245127     8.237132     8.241173
# 4   16125    B    A  ...     8.245127     8.237132     8.241173
#
# [5 rows x 32 columns]
# {'A': 8.278300774702961, 'B': 8.240344561542027, 'C': 8.309070792022533, 'D': 8.292381612789326}
#        id cat0 cat1  ... tar_enc_cat2 tar_enc_cat3 tar_enc_cat4
# 0  214778    A    B  ...     8.244570     8.236195     8.240345
# 1   91330    A    B  ...     8.244570     8.236195     8.240345
# 2   95512    A    B  ...     8.222841     8.236195     8.240345
# 3  106711    A    B  ...     8.244570     8.236195     8.240345
# 4  212946    B    A  ...     8.244570     8.236195     8.240345
#
# [5 rows x 32 columns]
# {'A': 8.283325960242708, 'B': 8.239564271301886, 'C': 8.315509239308115, 'D': 8.26429316197181}
#        id cat0 cat1  ... tar_enc_cat2 tar_enc_cat3 tar_enc_cat4
# 0  424309    B    A  ...     8.243585     8.235271     8.239564
# 1  373239    A    B  ...     8.243585     8.235271     8.283326
# 2  493757    B    B  ...     8.243585     8.235271     8.239564
# 3   24125    A    A  ...     8.243585     8.235271     8.239564
# 4  312331    A    A  ...     8.243585     8.235271     8.239564
#
# [5 rows x 32 columns]
# df            id cat0 cat1  ... tar_enc_cat2 tar_enc_cat3 tar_enc_cat4
# 0       97127    A    A  ...     8.244616     8.272189     8.240932
# 1       28518    A    A  ...     8.244616     8.237106     8.240932
# 2      289922    B    A  ...     8.224856     8.237106     8.240932
# 3      265997    B    A  ...     8.244616     8.237106     8.240932
# 4      103360    B    A  ...     8.244616     8.237106     8.240932
# ...       ...  ...  ...  ...          ...          ...          ...
# 47935  459632    A    A  ...     8.243585     8.235271     8.239564
# 47936  432458    B    A  ...     8.243585     8.235271     8.239564
# 47937  413623    A    A  ...     8.243585     8.235271     8.239564
# 47938  158228    A    B  ...     8.243585     8.235271     8.239564
# 47939  170223    A    A  ...     8.243585     8.235271     8.239564
#
# [240000 rows x 32 columns]
# {'A': 8.257873657747636, 'B': 8.230900383199218, 'C': 8.273415272468487, 'D': 8.24851921221706}
#        id cat0 cat1  ... tar_enc_cat3 tar_enc_cat4 tar_enc_cat5
# 0   97127    A    A  ...     8.272189     8.240932     8.230900
# 1   28518    A    A  ...     8.237106     8.240932     8.230900
# 2  289922    B    A  ...     8.237106     8.240932     8.230900
# 3  265997    B    A  ...     8.237106     8.240932     8.248519
# 4  103360    B    A  ...     8.237106     8.240932     8.248519
#
# [5 rows x 33 columns]
# {'A': 8.26984070791912, 'B': 8.23032072704292, 'C': 8.268588454809532, 'D': 8.249300289544}
#        id cat0 cat1  ... tar_enc_cat3 tar_enc_cat4 tar_enc_cat5
# 0  488880    B    B  ...     8.236432     8.240741     8.230321
# 1  357806    A    B  ...     8.236432     8.240741     8.230321
# 2   41431    B    B  ...     8.236432     8.240741     8.230321
# 3  188016    A    A  ...     8.236432     8.240741     8.249300
# 4  327993    A    A  ...     8.236432     8.240741     8.230321
#
# [5 rows x 33 columns]
# {'A': 8.250295959171533, 'B': 8.230672859966678, 'C': 8.271647322825636, 'D': 8.250451309581988}
#        id cat0 cat1  ... tar_enc_cat3 tar_enc_cat4 tar_enc_cat5
# 0  144377    A    A  ...     8.237132     8.241173     8.250451
# 1  371205    A    B  ...     8.275834     8.241173     8.230673
# 2   10724    B    A  ...     8.237132     8.241173     8.250451
# 3  368563    B    A  ...     8.237132     8.241173     8.250451
# 4   16125    B    A  ...     8.237132     8.241173     8.250296
#
# [5 rows x 33 columns]
# {'A': 8.253528853707003, 'B': 8.230291422071346, 'C': 8.271511678598413, 'D': 8.248870578233001}
#        id cat0 cat1  ... tar_enc_cat3 tar_enc_cat4 tar_enc_cat5
# 0  214778    A    B  ...     8.236195     8.240345     8.230291
# 1   91330    A    B  ...     8.236195     8.240345     8.271512
# 2   95512    A    B  ...     8.236195     8.240345     8.230291
# 3  106711    A    B  ...     8.236195     8.240345     8.271512
# 4  212946    B    A  ...     8.236195     8.240345     8.230291
#
# [5 rows x 33 columns]
# {'A': 8.249177544939228, 'B': 8.229950657297287, 'C': 8.27388843120868, 'D': 8.247278575158052}
#        id cat0 cat1  ... tar_enc_cat3 tar_enc_cat4 tar_enc_cat5
# 0  424309    B    A  ...     8.235271     8.239564     8.247279
# 1  373239    A    B  ...     8.235271     8.283326     8.229951
# 2  493757    B    B  ...     8.235271     8.239564     8.247279
# 3   24125    A    A  ...     8.235271     8.239564     8.247279
# 4  312331    A    A  ...     8.235271     8.239564     8.247279
#
# [5 rows x 33 columns]
# df            id cat0 cat1  ... tar_enc_cat3 tar_enc_cat4 tar_enc_cat5
# 0       97127    A    A  ...     8.272189     8.240932     8.230900
# 1       28518    A    A  ...     8.237106     8.240932     8.230900
# 2      289922    B    A  ...     8.237106     8.240932     8.230900
# 3      265997    B    A  ...     8.237106     8.240932     8.248519
# 4      103360    B    A  ...     8.237106     8.240932     8.248519
# ...       ...  ...  ...  ...          ...          ...          ...
# 47935  459632    A    A  ...     8.235271     8.239564     8.247279
# 47936  432458    B    A  ...     8.235271     8.239564     8.247279
# 47937  413623    A    A  ...     8.235271     8.239564     8.229951
# 47938  158228    A    B  ...     8.235271     8.239564     8.247279
# 47939  170223    A    A  ...     8.235271     8.239564     8.229951
#
# [240000 rows x 33 columns]
# {'A': 8.240454109248809, 'B': 8.277126888559392, 'C': 8.28139605424448, 'D': 8.28949294413886, 'E': 8.2683862375334, 'G': 7.9361295729722094, 'H': 8.223216513969227, 'I': 8.232583610833549}
#        id cat0 cat1  ... tar_enc_cat4 tar_enc_cat5 tar_enc_cat6
# 0   97127    A    A  ...     8.240932     8.230900     8.240454
# 1   28518    A    A  ...     8.240932     8.230900     8.240454
# 2  289922    B    A  ...     8.240932     8.230900     8.240454
# 3  265997    B    A  ...     8.240932     8.248519     8.240454
# 4  103360    B    A  ...     8.240932     8.248519     8.240454
#
# [5 rows x 34 columns]
# {'A': 8.240218690283612, 'B': 8.276949217488282, 'C': 8.296642234350223, 'D': 8.335328979443709, 'E': 8.46718523329666, 'G': 7.856733688220803, 'H': 8.11065243370988, 'I': 8.253584202930094}
#        id cat0 cat1  ... tar_enc_cat4 tar_enc_cat5 tar_enc_cat6
# 0  488880    B    B  ...     8.240741     8.230321     8.240219
# 1  357806    A    B  ...     8.240741     8.230321     8.240219
# 2   41431    B    B  ...     8.240741     8.230321     8.240219
# 3  188016    A    A  ...     8.240741     8.249300     8.240219
# 4  327993    A    A  ...     8.240741     8.230321     8.240219
#
# [5 rows x 34 columns]
# {'A': 8.240808752648812, 'B': 8.276190851134288, 'C': 8.32551103636457, 'D': 8.2870947020478, 'E': 8.379665597947994, 'G': 7.886590098877286, 'H': 8.248343900731443, 'I': 8.208229228503754}
#        id cat0 cat1  ... tar_enc_cat4 tar_enc_cat5 tar_enc_cat6
# 0  144377    A    A  ...     8.241173     8.250451     8.240809
# 1  371205    A    B  ...     8.241173     8.230673     8.240809
# 2   10724    B    A  ...     8.241173     8.250451     8.240809
# 3  368563    B    A  ...     8.241173     8.250451     8.240809
# 4   16125    B    A  ...     8.241173     8.250296     8.240809
#
# [5 rows x 34 columns]
# {'A': 8.240002668670229, 'B': 8.272274761011793, 'C': 8.322266796512409, 'D': 8.322855136738967, 'E': 8.301101937621306, 'G': 8.061383112979058, 'H': 8.245030720841562, 'I': 8.26589541361091}
#        id cat0 cat1  ... tar_enc_cat4 tar_enc_cat5 tar_enc_cat6
# 0  214778    A    B  ...     8.240345     8.230291     8.240003
# 1   91330    A    B  ...     8.240345     8.271512     8.240003
# 2   95512    A    B  ...     8.240345     8.230291     8.240003
# 3  106711    A    B  ...     8.240345     8.271512     8.240003
# 4  212946    B    A  ...     8.240345     8.230291     8.240003
#
# [5 rows x 34 columns]
# {'A': 8.23923949242403, 'B': 8.277688046538705, 'C': 8.286387495172134, 'D': 8.3416285795187, 'E': 8.331974983527182, 'G': 8.029630771460972, 'H': 8.19497549440362, 'I': 8.197115381021101}
#        id cat0 cat1  ... tar_enc_cat4 tar_enc_cat5 tar_enc_cat6
# 0  424309    B    A  ...     8.239564     8.247279     8.239239
# 1  373239    A    B  ...     8.283326     8.229951     8.239239
# 2  493757    B    B  ...     8.239564     8.247279     8.239239
# 3   24125    A    A  ...     8.239564     8.247279     8.239239
# 4  312331    A    A  ...     8.239564     8.247279     8.239239
#
# [5 rows x 34 columns]
# df            id cat0 cat1  ... tar_enc_cat4 tar_enc_cat5 tar_enc_cat6
# 0       97127    A    A  ...     8.240932     8.230900     8.240454
# 1       28518    A    A  ...     8.240932     8.230900     8.240454
# 2      289922    B    A  ...     8.240932     8.230900     8.240454
# 3      265997    B    A  ...     8.240932     8.248519     8.240454
# 4      103360    B    A  ...     8.240932     8.248519     8.240454
# ...       ...  ...  ...  ...          ...          ...          ...
# 47935  459632    A    A  ...     8.239564     8.247279     8.239239
# 47936  432458    B    A  ...     8.239564     8.247279     8.239239
# 47937  413623    A    A  ...     8.239564     8.229951     8.239239
# 47938  158228    A    B  ...     8.239564     8.247279     8.239239
# 47939  170223    A    A  ...     8.239564     8.229951     8.239239
#
# [240000 rows x 34 columns]
# {'A': 8.150477871081454, 'B': 8.258304443716732, 'C': 8.533554001887726, 'D': 8.253528300012011, 'E': 8.240275011167096, 'F': 8.305202347062542, 'G': 8.256377404609909, 'I': 7.952679694045845}
#        id cat0 cat1  ... tar_enc_cat5 tar_enc_cat6 tar_enc_cat7
# 0   97127    A    A  ...     8.230900     8.240454     8.240275
# 1   28518    A    A  ...     8.230900     8.240454     8.240275
# 2  289922    B    A  ...     8.230900     8.240454     8.240275
# 3  265997    B    A  ...     8.248519     8.240454     8.240275
# 4  103360    B    A  ...     8.248519     8.240454     8.240275
#
# [5 rows x 35 columns]
# {'A': 8.095487190191303, 'B': 8.265292778235871, 'C': 8.499560919822095, 'D': 8.254215017543576, 'E': 8.239956060638807, 'F': 8.317827352930324, 'G': 8.248177125124933, 'I': 8.101559743237486}
#        id cat0 cat1  ... tar_enc_cat5 tar_enc_cat6 tar_enc_cat7
# 0  488880    B    B  ...     8.230321     8.240219     8.239956
# 1  357806    A    B  ...     8.230321     8.240219     8.239956
# 2   41431    B    B  ...     8.230321     8.240219     8.239956
# 3  188016    A    A  ...     8.249300     8.240219     8.239956
# 4  327993    A    A  ...     8.230321     8.240219     8.239956
#
# [5 rows x 35 columns]
# {'A': 8.321436263892307, 'B': 8.265641871282416, 'C': 8.349437553970226, 'D': 8.255759663615175, 'E': 8.240583901196366, 'F': 8.31277019649987, 'G': 8.243113779300895, 'I': 7.918193200093087}
#        id cat0 cat1  ... tar_enc_cat5 tar_enc_cat6 tar_enc_cat7
# 0  144377    A    A  ...     8.250451     8.240809     8.265642
# 1  371205    A    B  ...     8.230673     8.240809     8.240584
# 2   10724    B    A  ...     8.250451     8.240809     8.240584
# 3  368563    B    A  ...     8.250451     8.240809     8.240584
# 4   16125    B    A  ...     8.250296     8.240809     8.240584
#
# [5 rows x 35 columns]
# {'A': 8.228899083911905, 'B': 8.258917360909436, 'C': 8.468686734206797, 'D': 8.257529112445964, 'E': 8.23949901468274, 'F': 8.314810585219542, 'G': 8.270331136377365, 'I': 8.027131375778309}
#        id cat0 cat1  ... tar_enc_cat5 tar_enc_cat6 tar_enc_cat7
# 0  214778    A    B  ...     8.230291     8.240003     8.239499
# 1   91330    A    B  ...     8.271512     8.240003     8.239499
# 2   95512    A    B  ...     8.230291     8.240003     8.239499
# 3  106711    A    B  ...     8.271512     8.240003     8.257529
# 4  212946    B    A  ...     8.230291     8.240003     8.239499
#
# [5 rows x 35 columns]
# {'A': 8.358270863914672, 'B': 8.26081957317009, 'C': 8.479716033935105, 'D': 8.253819597900542, 'E': 8.238971559457722, 'F': 8.306357245036473, 'G': 8.255779754880889, 'I': 8.092845784780401}
#        id cat0 cat1  ... tar_enc_cat5 tar_enc_cat6 tar_enc_cat7
# 0  424309    B    A  ...     8.247279     8.239239     8.238972
# 1  373239    A    B  ...     8.229951     8.239239     8.238972
# 2  493757    B    B  ...     8.247279     8.239239     8.253820
# 3   24125    A    A  ...     8.247279     8.239239     8.238972
# 4  312331    A    A  ...     8.247279     8.239239     8.238972
#
# [5 rows x 35 columns]
# df            id cat0 cat1  ... tar_enc_cat5 tar_enc_cat6 tar_enc_cat7
# 0       97127    A    A  ...     8.230900     8.240454     8.240275
# 1       28518    A    A  ...     8.230900     8.240454     8.240275
# 2      289922    B    A  ...     8.230900     8.240454     8.240275
# 3      265997    B    A  ...     8.248519     8.240454     8.240275
# 4      103360    B    A  ...     8.248519     8.240454     8.240275
# ...       ...  ...  ...  ...          ...          ...          ...
# 47935  459632    A    A  ...     8.247279     8.239239     8.238972
# 47936  432458    B    A  ...     8.247279     8.239239     8.238972
# 47937  413623    A    A  ...     8.229951     8.239239     8.238972
# 47938  158228    A    B  ...     8.247279     8.239239     8.238972
# 47939  170223    A    A  ...     8.229951     8.239239     8.238972
#
# [240000 rows x 35 columns]
# {'A': 8.230704692125173, 'B': 8.198025686924636, 'C': 8.283028994441233, 'D': 8.238083840546775, 'E': 8.194158174926464, 'F': 8.19519042296725, 'G': 8.24456951187454}
#        id cat0 cat1  ... tar_enc_cat6 tar_enc_cat7 tar_enc_cat8
# 0   97127    A    A  ...     8.240454     8.240275     8.283029
# 1   28518    A    A  ...     8.240454     8.240275     8.194158
# 2  289922    B    A  ...     8.240454     8.240275     8.194158
# 3  265997    B    A  ...     8.240454     8.240275     8.244570
# 4  103360    B    A  ...     8.240454     8.240275     8.283029
#
# [5 rows x 36 columns]
# {'A': 8.22988220910596, 'B': 8.195444373114489, 'C': 8.28253321084452, 'D': 8.236467523708063, 'E': 8.193184567147329, 'F': 8.226928590232287, 'G': 8.250429195878317}
#        id cat0 cat1  ... tar_enc_cat6 tar_enc_cat7 tar_enc_cat8
# 0  488880    B    B  ...     8.240219     8.239956     8.193185
# 1  357806    A    B  ...     8.240219     8.239956     8.193185
# 2   41431    B    B  ...     8.240219     8.239956     8.282533
# 3  188016    A    A  ...     8.240219     8.239956     8.229882
# 4  327993    A    A  ...     8.240219     8.239956     8.193185
#
# [5 rows x 36 columns]
# {'A': 8.231632948560593, 'B': 8.151760040204811, 'C': 8.283919271517917, 'D': 8.226503142439984, 'E': 8.193084173725854, 'F': 8.203587873872246, 'G': 8.24964819959358}
#        id cat0 cat1  ... tar_enc_cat6 tar_enc_cat7 tar_enc_cat8
# 0  144377    A    A  ...     8.240809     8.265642     8.231633
# 1  371205    A    B  ...     8.240809     8.240584     8.193084
# 2   10724    B    A  ...     8.240809     8.240584     8.231633
# 3  368563    B    A  ...     8.240809     8.240584     8.249648
# 4   16125    B    A  ...     8.240809     8.240584     8.283919
#
# [5 rows x 36 columns]
# {'A': 8.228270836149353, 'B': 8.223484082028225, 'C': 8.284536992215815, 'D': 8.244288832937924, 'E': 8.19127113534399, 'F': 8.196599529430772, 'G': 8.249681031894305}
#        id cat0 cat1  ... tar_enc_cat6 tar_enc_cat7 tar_enc_cat8
# 0  214778    A    B  ...     8.240003     8.239499     8.284537
# 1   91330    A    B  ...     8.240003     8.239499     8.228271
# 2   95512    A    B  ...     8.240003     8.239499     8.191271
# 3  106711    A    B  ...     8.240003     8.257529     8.249681
# 4  212946    B    A  ...     8.240003     8.239499     8.228271
#
# [5 rows x 36 columns]
# {'A': 8.228073367731957, 'B': 8.13941955289744, 'C': 8.28282541671231, 'D': 8.247854484274647, 'E': 8.192279538198989, 'F': 8.217801871673592, 'G': 8.245241498765333}
#        id cat0 cat1  ... tar_enc_cat6 tar_enc_cat7 tar_enc_cat8
# 0  424309    B    A  ...     8.239239     8.238972     8.245241
# 1  373239    A    B  ...     8.239239     8.238972     8.247854
# 2  493757    B    B  ...     8.239239     8.253820     8.192280
# 3   24125    A    A  ...     8.239239     8.238972     8.228073
# 4  312331    A    A  ...     8.239239     8.238972     8.282825
#
# [5 rows x 36 columns]
# df            id cat0 cat1  ... tar_enc_cat6 tar_enc_cat7 tar_enc_cat8
# 0       97127    A    A  ...     8.240454     8.240275     8.283029
# 1       28518    A    A  ...     8.240454     8.240275     8.194158
# 2      289922    B    A  ...     8.240454     8.240275     8.194158
# 3      265997    B    A  ...     8.240454     8.240275     8.244570
# 4      103360    B    A  ...     8.240454     8.240275     8.283029
# ...       ...  ...  ...  ...          ...          ...          ...
# 47935  459632    A    A  ...     8.239239     8.238972     8.228073
# 47936  432458    B    A  ...     8.239239     8.238972     8.247854
# 47937  413623    A    A  ...     8.239239     8.238972     8.282825
# 47938  158228    A    B  ...     8.239239     8.238972     8.282825
# 47939  170223    A    A  ...     8.239239     8.238972     8.192280
#
# [240000 rows x 36 columns]
# {'A': 8.240197732822361, 'B': 8.23638623652875, 'C': 8.222221802608358, 'D': 8.21848879057132, 'E': 8.303511432807625, 'F': 8.2585044835648, 'G': 8.231875658885272, 'H': 8.244306880330022, 'I': 8.223779469436629, 'J': 8.227263092101277, 'K': 8.267575293739522, 'L': 8.240478567752511, 'M': 8.230744731318143, 'N': 8.245560932115282, 'O': 8.236317834138589}
#        id cat0 cat1  ... tar_enc_cat7 tar_enc_cat8 tar_enc_cat9
# 0   97127    A    A  ...     8.240275     8.283029     8.240479
# 1   28518    A    A  ...     8.240275     8.194158     8.258504
# 2  289922    B    A  ...     8.240275     8.194158     8.223779
# 3  265997    B    A  ...     8.240275     8.244570     8.236318
# 4  103360    B    A  ...     8.240275     8.283029     8.236386
#
# [5 rows x 37 columns]
# {'A': 8.229443469108546, 'B': 8.243152498115062, 'C': 8.22182660321284, 'D': 8.206550011390965, 'E': 8.315743063531471, 'F': 8.257921880871951, 'G': 8.227854111335441, 'H': 8.243563320478678, 'I': 8.225492794258054, 'J': 8.228566808213206, 'K': 8.264764263607029, 'L': 8.234324090090768, 'M': 8.237440822241771, 'N': 8.256698058736431, 'O': 8.235307449765378}
#        id cat0 cat1  ... tar_enc_cat7 tar_enc_cat8 tar_enc_cat9
# 0  488880    B    B  ...     8.239956     8.193185     8.221827
# 1  357806    A    B  ...     8.239956     8.193185     8.243152
# 2   41431    B    B  ...     8.239956     8.282533     8.243152
# 3  188016    A    A  ...     8.239956     8.229882     8.227854
# 4  327993    A    A  ...     8.239956     8.193185     8.257922
#
# [5 rows x 37 columns]
# {'A': 8.232156037299063, 'B': 8.24038385154537, 'C': 8.225580599939352, 'D': 8.207222563073497, 'E': 8.254097529412146, 'F': 8.256546209518898, 'G': 8.231531118015324, 'H': 8.239695257434255, 'I': 8.226158163318003, 'J': 8.228026411291676, 'K': 8.269483810749671, 'L': 8.244414467624388, 'M': 8.238809486460386, 'N': 8.247148021878955, 'O': 8.244712865458101}
#        id cat0 cat1  ... tar_enc_cat7 tar_enc_cat8 tar_enc_cat9
# 0  144377    A    A  ...     8.265642     8.231633     8.226158
# 1  371205    A    B  ...     8.240584     8.193084     8.247148
# 2   10724    B    A  ...     8.240584     8.231633     8.244713
# 3  368563    B    A  ...     8.240584     8.249648     8.228026
# 4   16125    B    A  ...     8.240584     8.283919     8.226158
#
# [5 rows x 37 columns]
# {'A': 8.23625289734112, 'B': 8.236072739330515, 'C': 8.211154804420051, 'D': 8.210816667030226, 'E': 8.304197455330206, 'F': 8.258923290426162, 'G': 8.233107493974217, 'H': 8.240979902222367, 'I': 8.22375752536287, 'J': 8.22540581840983, 'K': 8.270211162850645, 'L': 8.238822776980223, 'M': 8.236409231801979, 'N': 8.240875007988537, 'O': 8.237578162649893}
#        id cat0 cat1  ... tar_enc_cat7 tar_enc_cat8 tar_enc_cat9
# 0  214778    A    B  ...     8.239499     8.284537     8.223758
# 1   91330    A    B  ...     8.239499     8.228271     8.258923
# 2   95512    A    B  ...     8.239499     8.191271     8.240980
# 3  106711    A    B  ...     8.257529     8.249681     8.240980
# 4  212946    B    A  ...     8.239499     8.228271     8.236253
#
# [5 rows x 37 columns]
# {'A': 8.22495304782222, 'B': 8.238265952322902, 'C': 8.230205066892902, 'D': 8.218796784528653, 'E': 8.27192424552718, 'F': 8.258389718894447, 'G': 8.233697906538993, 'H': 8.24390026585689, 'I': 8.22468428292771, 'J': 8.222125855436555, 'K': 8.2653018614395, 'L': 8.240115899225495, 'M': 8.22669942226526, 'N': 8.239629552807008, 'O': 8.23656048338889}
#        id cat0 cat1  ... tar_enc_cat7 tar_enc_cat8 tar_enc_cat9
# 0  424309    B    A  ...     8.238972     8.245241     8.233698
# 1  373239    A    B  ...     8.238972     8.247854     8.240116
# 2  493757    B    B  ...     8.253820     8.192280     8.258390
# 3   24125    A    A  ...     8.238972     8.228073     8.258390
# 4  312331    A    A  ...     8.238972     8.282825     8.224953
#
# [5 rows x 37 columns]
# df            id cat0 cat1  ... tar_enc_cat7 tar_enc_cat8 tar_enc_cat9
# 0       97127    A    A  ...     8.240275     8.283029     8.240479
# 1       28518    A    A  ...     8.240275     8.194158     8.258504
# 2      289922    B    A  ...     8.240275     8.194158     8.223779
# 3      265997    B    A  ...     8.240275     8.244570     8.236318
# 4      103360    B    A  ...     8.240275     8.283029     8.236386
# ...       ...  ...  ...  ...          ...          ...          ...
# 47935  459632    A    A  ...     8.238972     8.228073     8.224684
# 47936  432458    B    A  ...     8.238972     8.247854     8.224684
# 47937  413623    A    A  ...     8.238972     8.282825     8.224684
# 47938  158228    A    B  ...     8.238972     8.282825     8.222126
# 47939  170223    A    A  ...     8.238972     8.192280     8.226699
#
# [240000 rows x 37 columns]

# %%
df_test = df_test[useful_features]

# %%
#For this GPU is required
#Note: GPU hist doesnt give much great results, so tune the parameter in gpu and take those best params and use it to predict in CPU
def run(trial):
    fold=0
    #some examples of parameters for xgboost:
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-2, log=True)
    reg_lambda = trial.suggest_loguniform("reg_lambda", 1e-8, 100.0)
    reg_alpha = trial.suggest_loguniform("reg_alpha", 1e-8, 100.0)
    subsample = trial.suggest_float("subsample", 0.1, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.1, 1.0)
    max_depth = trial.suggest_int("max_depth", 1, 7)
    
    
    xtrain = df[df.kfold != fold].reset_index(drop=True)
    xvalid = df[df.kfold == fold].reset_index(drop=True)
    
    ytrain = xtrain.target
    yvalid = xvalid.target
    
    xtrain = xtrain[useful_features]
    xvalid = xvalid[useful_features]
    
    ordinalencoder = preprocessing.OrdinalEncoder()
    xtrain[object_cols] = ordinalencoder.fit_transform(xtrain[object_cols])
    xvalid[object_cols] = ordinalencoder.transform(xvalid[object_cols])
    
    model = XGBRegressor(random_state=42,
                        #tree_method = "gpu_hist",
                        #gpu_id = "1",
                        #predictor = "gpu_predictor",
                        n_estimators = 200,
                        learning_rate =learning_rate,
                        reg_lambda = reg_lambda,
                        reg_alpha = reg_alpha,
                        subsample = subsample, 
                        colsample_bytree = colsample_bytree,
                        max_depth = max_depth,)
    model.fit(xtrain, ytrain, early_stopping_rounds=100, eval_set =[(xvalid, yvalid)], verbose=1000)
    pred_valid = model.predict(xvalid)
    rmse = mean_squared_error(y_true=yvalid, y_pred=pred_valid, squared=False)
    return rmse

# %%
#here we are specifying minimize since we wanted to optimize the rmse score:
study = optuna.create_study(direction = "minimize")
study.optimize(run, n_trials=5)

#Print the best parameters:
study.best_params
# Out:
# [I 2023-05-16 21:56:33,939] A new study created in memory with name: no-name-b1d5bbbf-132a-48c5-9096-d0a09016c5e9
# [0]	validation_0-rmse:7.71773
# [199]	validation_0-rmse:1.83691
# [I 2023-05-16 21:56:41,024] Trial 0 finished with value: 1.8369129136751796 and parameters: {'learning_rate': 0.00761406470599245, 'reg_lambda': 0.011805311808314534, 'reg_alpha': 88.26953706323562, 'subsample': 0.3823448694972297, 'colsample_bytree': 0.4795130865215185, 'max_depth': 2}. Best is trial 0 with value: 1.8369129136751796.
# [0]	validation_0-rmse:7.77574
# [199]	validation_0-rmse:7.64842
# [I 2023-05-16 21:56:48,723] Trial 1 finished with value: 7.6484207924682615 and parameters: {'learning_rate': 8.374908887543265e-05, 'reg_lambda': 17.733011282161932, 'reg_alpha': 0.0005951469797068024, 'subsample': 0.374830851517874, 'colsample_bytree': 0.7887392712816126, 'max_depth': 6}. Best is trial 0 with value: 1.8369129136751796.
# [0]	validation_0-rmse:7.77628
# [199]	validation_0-rmse:7.75564
# [I 2023-05-16 21:56:59,786] Trial 2 finished with value: 7.755639456905614 and parameters: {'learning_rate': 1.3476639756894046e-05, 'reg_lambda': 0.021783328860354112, 'reg_alpha': 2.9809748731059723e-07, 'subsample': 0.6759219277211678, 'colsample_bytree': 0.17035763068373644, 'max_depth': 3}. Best is trial 0 with value: 1.8369129136751796.
# [0]	validation_0-rmse:7.77561
# [199]	validation_0-rmse:7.62336
# [I 2023-05-16 21:57:04,264] Trial 3 finished with value: 7.623361659888947 and parameters: {'learning_rate': 0.00010028943444929665, 'reg_lambda': 4.1854526520695916e-08, 'reg_alpha': 1.5086348710080711e-05, 'subsample': 0.14817767805347645, 'colsample_bytree': 0.10109231193521442, 'max_depth': 1}. Best is trial 0 with value: 1.8369129136751796.
# [0]	validation_0-rmse:7.75453
# [199]	validation_0-rmse:4.44907
# [I 2023-05-16 21:57:12,271] Trial 4 finished with value: 4.449070852338091 and parameters: {'learning_rate': 0.0028359892174821193, 'reg_lambda': 20.083851098961016, 'reg_alpha': 3.3856494175545493e-06, 'subsample': 0.8395102804934238, 'colsample_bytree': 0.7038628425590557, 'max_depth': 6}. Best is trial 0 with value: 1.8369129136751796.
# {'learning_rate': 0.00761406470599245,
#  'reg_lambda': 0.011805311808314534,
#  'reg_alpha': 88.26953706323562,
#  'subsample': 0.3823448694972297,
#  'colsample_bytree': 0.4795130865215185,
#  'max_depth': 2}
